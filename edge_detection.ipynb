# %% [markdown]
# <a href="https://colab.research.google.com/github/spongebob436/ML/blob/main/edge_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import requests

# %%
with open('/content/car.jpeg', 'rb') as src_file:
    with open('test.jpg', 'wb') as dest_file:
        dest_file.write(src_file.read())

# %%
img = cv2.imread('test.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=299x169>

# %%
# making  the img as grayscale as color isnt required for edge detection
img_gray= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=299x169>

# %%
#Bluring the image to reduce the noise:
img_blur=cv2.GaussianBlur(img_gray,(3,3),0)
cv2_imshow(img_blur)
# Out:
# <PIL.Image.Image image mode=L size=299x169>

# %%
# Sobel Edge Detection

# %%
sobelxy= cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5)
cv2_imshow(sobelxy)
# Out:
# <PIL.Image.Image image mode=L size=299x169>

# %%
# Canny edge Detection
edges= cv2.Canny(image=img_blur, threshold1=100, threshold2=200)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=299x169>
