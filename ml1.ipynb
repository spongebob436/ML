# %% [markdown]
# <a href="https://colab.research.google.com/github/spongebob436/ML/blob/ml1/ml1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path= "/content/drive/MyDrive/dataset/car-sales.csv"
df=pd.read_csv(path)
df.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
# %matplotlib inline
plt.xlabel('Type')
plt.ylabel('Price')
plt.scatter(df.Make,df.Price.colour='red',marker='+')
# Out:
#   File "<ipython-input-11-a1fb0c811414>", line 4
#     plt.scatter(df.Make,df.Price.colour='red',marker='+')
#                         ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
